# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %% [markdown]
# ### This is a playground!
#
# Here you can quickly test some code, visualize your data

# %%
from Project import project
from data import MyDataset
from utils import show_dataset
from data.transformation import val_transform

ds = MyDataset.from_dir(project.data_dir / 'train', transform=val_transform)

# %%
show_dataset(ds, n=2)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10,10)

show_dataset(ds, n=len(ds))
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
